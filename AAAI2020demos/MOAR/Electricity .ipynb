# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open('/Users/ivanbaybuza/Documents/научка/AAAI2020%20public%20TS%20and%20demos/Public TS datasets/ele_big.npy', 'rb') as file:
    ele_big = pickle.load(file)

# %%
ele_big[:,0]
# Out:
# array([31.70833333, 31.79166667, 31.70833333, ..., 67.        ,
#        66.91666667, 67.25      ])

# %%
plt.figure()

plt.subplot(221)
plt.plot(ele_big[:,0])

plt.subplot(222)
plt.plot(ele_big[:,1])

plt.subplot(223)
plt.plot(ele_big[:,2])

plt.subplot(224)
plt.plot(ele_big[:,3])

# %%
a = MOAR(ele_big)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-4c654bf3b4d3> in <module>
# ----> 1 a = MOAR(ele_big)
#
# TypeError: 'module' object is not callable

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
# %run ./MOAR.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Documents/научка/AAAI2020%20public%20TS%20and%20demos/MOAR/MOAR.py in <module>
#      70     max_iter_num = 100
#      71
# ---> 72     with open('ushcn.npy', 'rb') as file:
#      73         data = pkl.load(file)
#      74
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ushcn.npy'

# %%
import MOAR

# %%
import base
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-49-21a72946d959> in <module>
# ----> 1 import base
#
# ModuleNotFoundError: No module named 'base'
