# %%
import pickle
import matplotlib.pyplot as plt

# %%
import MOAR

# %%
with open('/Users/ivanbaybuza/Documents/science/AAAI2020demos/Public TS datasets/ele_big.npy', 'rb') as file:
    ele_big = pickle.load(file)

# %%
plt.figure()

plt.subplot(221)
plt.plot(ele_big[:,0])

plt.subplot(222)
plt.plot(ele_big[:,1])

plt.subplot(223)
plt.plot(ele_big[:,2])

plt.subplot(224)
plt.plot(ele_big[:,3])

# %%
T = X.shape[-1]
T
# Out:
# 321

# %%
X=ele_big
dims = X[..., 0].shape

# %%
dims
X.shape
enumerate(list(range(len(dims))))

# %%
from MOAR import MOAR as M

# %%
m = 2
max_iter_num = 2
U, ar = M(X=ele_big, core=[50, 1], m=m, max_iter_num=max_iter_num)
# Out:
# U change: 1.420322739319313
# U change: 1.2961486056551161
